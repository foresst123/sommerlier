# %% [markdown]
# # Sommelier — Vietnamese UV Isolated Venv Test on Google Colab
#
# Runs the sommelier podcast pipeline inside a **clean isolated `venv`** (`/content/sommelier_env`) using **`uv`** to install minimal dependencies and automatically pulls audio clips from YouTube via `scripts/pick_clips.py`.

# %% [markdown]
# ## 1. Sanity check the runtime

# %%
# !nvidia-smi -L
# !python --version
# !df -h /content | tail -1
import torch
print('torch', torch.__version__, 'cuda', torch.version.cuda, 'avail', torch.cuda.is_available())
# Out:
# GPU 0: Tesla T4 (UUID: GPU-fd8ec6a1-84c6-a0da-d43c-19e8e5508a5b)
# Python 3.12.13
# overlay         113G   57G   57G  51% /
# torch 2.11.0+cu128 cuda 12.8 avail True

# %% [markdown]
# ## 2. Clone the repo
#
# If you're iterating on the `--lang vi` integration, swap in your fork's URL.

# %%
# %cd /content
![ -d sommelier ] || git clone https://github.com/tuanad121/sommelier.git
# %cd /content/sommelier/podcast-pipeline
# Out:
# /content
# /content/sommelier/podcast-pipeline

# %% [markdown]
# ## 3. Install dependencies (~15 min)
#
# Mirrors the README's three-step install order (torch first, then requirements, then re-pin torch). Adds the `chunkformer` package on top for the VN MoE third slot.

# %%
# 1. Install uv package manager
# !pip install -q uv yt-dlp

# 2. Create clean isolated virtual environment on Colab
# !uv venv --allow-existing /content/sommelier_env

# 3. Define proposed optimized dependencies list (resolved & conflict-free)
PROPOSED_REQUIREMENTS = """
numpy==1.26.4
torch==2.7.1
torchaudio==2.7.1
torchvision==0.22.1
lightning==2.3.3
torchmetrics==1.7.4
onnxruntime-gpu
nemo-toolkit[asr]==2.5.3
pyannote.audio==3.3.2
speechbrain==1.0.3
faster-whisper==1.1.0
whisperx==3.3.1
chunkformer
ctranslate2>=4.0.0,<5.0.0
demucs>=4.0.0
panns-inference
librosa==0.11.0
soundfile==0.13.1
pydub==0.25.1
julius==0.2.7
numba==0.61.2
transformers==4.53.0
huggingface-hub==0.33.4
g2pk
jamo
nltk==3.9.1
openai==1.97.1
tritony==0.0.20
tritonclient[all]
pandas==2.3.1
PyYAML==6.0.2
tqdm==4.67.1
wandb==0.21.0
requests==2.32.4
einops==0.8.1
hydra-core==1.3.2
omegaconf==2.3.0
yt-dlp
setuptools>=79.0.0
sacrebleu
"""

with open('requirements_proposed.txt', 'w') as f:
    f.write(PROPOSED_REQUIREMENTS.strip())

print('>>> Step 1: Pre-installing PyTorch CUDA 12.6 inside venv...')
# !uv pip install --python /content/sommelier_env torch==2.7.1 torchaudio==2.7.1 torchvision==0.22.1 --extra-index-url https://download.pytorch.org/whl/cu126

print('\n>>> Step 2: Testing resolution & installing proposed dependencies into isolated venv via UV (Realtime Log)...')
# !uv pip install --python /content/sommelier_env -r requirements_proposed.txt --extra-index-url https://download.pytorch.org/whl/cu126 --index-strategy unsafe-best-match
# Out:
# warning: The `--system` flag has no effect, `uv venv` always ignores virtual environments when finding a Python interpreter; did you mean `--no-managed-python`?
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: /content/sommelier_env
# Activate with: source /content/sommelier_env/bin/activate
# >>> Step 1: Pre-installing PyTorch CUDA 12.6 inside venv...
# Using Python 3.12.13 environment at: /content/sommelier_env
# Checked 3 packages in 8ms
#
# >>> Step 2: Testing resolution & installing proposed dependencies into isolated venv via UV (Realtime Log)...
# Using Python 3.12.13 environment at: /content/sommelier_env
# Resolved 263 packages in 1.34s
# Installed 2 packages in 5ms
#  + portalocker==4.1.0
#  + sacrebleu==2.6.0

# %%
# !uv pip uninstall --python /content/sommelier_env nvidia-resiliency-ext
# Out:
# Using Python 3.12.13 environment at: /content/sommelier_env
# warning: Skipping nvidia-resiliency-ext as it is not installed
# warning: No packages to uninstall

# %%
# Verify imports inside isolated venv
# !/content/sommelier_env/bin/python -c "import torch, whisperx, demucs, nemo, pyannote.audio, transformers; from chunkformer import ChunkFormerModel; print('vEnv Python:', torch.__version__, 'CUDA:', torch.cuda.is_available()); print('whisperx:', whisperx.__version__); print('transformers:', transformers.__version__); print('nemo:', nemo.__version__)"
# Out:
# [NeMo W 2026-08-14 05:02:18 nemo_logging:405] Megatron num_microbatches_calculator not found, using Apex version.
# OneLogger: Setting error_handling_strategy to DISABLE_QUIETLY_AND_REPORT_METRIC_ERROR for rank (rank=0) with OneLogger disabled. To override: explicitly set error_handling_strategy parameter.
# No exporters were provided. This means that no telemetry data will be collected.
# vEnv Python: 2.7.1+cu126 CUDA: True
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# AttributeError: module 'whisperx' has no attribute '__version__'

# %% [markdown]
# ## 4. Hugging Face authentication
#
# Pyannote diarization and Sortformer are gated. Accept the license on each model page first, then paste your token below.

# %%
from huggingface_hub import login
from getpass import getpass

hf_token = getpass('HF token (hf_...): ')
login(token=hf_token)

# Also write it to config.json so pipeline code that reads cfg['huggingface_token'] works.
import json, pathlib
cfg_path = pathlib.Path('/content/sommelier/podcast-pipeline/config.json')
cfg = json.loads(cfg_path.read_text())
cfg['huggingface_token'] = hf_token
cfg_path.write_text(json.dumps(cfg, indent=2, ensure_ascii=False))
print('config.json updated')
# Out:
# HF token (hf_...): ··········
# config.json updated

# %% [markdown]
# ## 5. Provide a Vietnamese audio clip
#
# Upload one short (~30–60 s) WAV/MP3. The pipeline expects a **folder** of audio, so we drop the file into `/content/vi_audio/`.

# %%
# Automated YouTube Audio Puller using scripts/pick_clips.py
import os, random, glob, shutil
from pathlib import Path

os.makedirs('/content/vi_audio', exist_ok=True)

# Create TSV file with target YouTube URL
yt_url = 'https://www.youtube.com/watch?v=ZzwZaHNqrVM'
tsv_path = '/content/yt_clip.tsv'
with open(tsv_path, 'w', encoding='utf-8') as f:
    f.write(f'yt_sample\t{yt_url}\t00:00\t03:00\tchannel_test\tpodcast\n')

print('>>> Pulling YouTube audio clip via pick_clips.py...')
# !/content/sommelier_env/bin/python /content/sommelier/scripts/pick_clips.py --tsv /content/yt_clip.tsv --out /content/vi_audio

# Pick a random WAV file in /content/vi_audio for the pipeline test
wav_files = glob.glob('/content/vi_audio/*.wav')
if wav_files:
    selected_wav = random.choice(wav_files)
    print(f'\n✅ Successfully pulled YouTube audio! Selected for pipeline: {selected_wav}')
else:
    print('❌ Warning: No WAV file produced by pick_clips.py. Please check yt-dlp output.')
# Out:
# >>> Pulling YouTube audio clip via pick_clips.py...
# Pulling 1 clips to /content/vi_audio/  (workers=1)
#   [pull] yt_sample  (180.0s)  https://www.youtube.com/watch?v=ZzwZaHNqrVM
#   [error] yt_sample: yt-dlp failed after 1 attempts: utube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] ZzwZaHNqrVM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
#
# Done: 0/1 clips downloaded to /content/vi_audio/
# ❌ Warning: No WAV file produced by pick_clips.py. Please check yt-dlp output.

# %% [markdown]
# ## 6. Run the pipeline (VN MoE, no Demucs/SepReformer for speed)
#
# Flags below disable Demucs, SepReformer, Qwen3-Omni captioning, and the LLM post-pass to keep the smoke test fast and minimize VRAM. Add them back once the basic VN flow works.

# %%
# !echo 'def declare_namespace(name): pass' > /content/sommelier_env/lib/python3.12/site-packages/pkg_resources.py
# !sed -i 's/def _patched_load(path_or_url: Union\[IO, str, Path\], map_location=None) -> Any:/def _patched_load(path_or_url: Union\[IO, str, Path\], map_location=None, weights_only=False, **kwargs) -> Any:/g' /content/sommelier/podcast-pipeline/main_original_ASR_MoE.py

# %%
# %cd /content/sommelier/podcast-pipeline
# !/content/sommelier_env/bin/python main_original_ASR_MoE.py \
  --input_folder_path /content/vi_audio \
  --lang vi \
  --vad \
  --dia3 \
  --ASRMoE \
  --no-demucs \
  --whisperx_word_timestamps \
  --no-qwen3omni \
  --no-sepreformer \
  --LLM case_0 \
  --seg_th 0.11 \
  --min_cluster_size 11 \
  --clust_th 0.5 \
  --merge_gap 2
# Out:
# /content/sommelier/podcast-pipeline
# [NeMo W 2026-08-14 05:04:16 nemo_logging:405] Megatron num_microbatches_calculator not found, using Apex version.
# OneLogger: Setting error_handling_strategy to DISABLE_QUIETLY_AND_REPORT_METRIC_ERROR for rank (rank=0) with OneLogger disabled. To override: explicitly set error_handling_strategy parameter.
# No exporters were provided. This means that no telemetry data will be collected.
# Initialize logger for main
# 2026-08-14 05:04:18,438 - main - INFO - Using input folder path: /content/vi_audio
# 2026-08-14 05:04:18,438 - main - DEBUG - Loading models...
# 2026-08-14 05:04:18,438 - main - INFO - ENV: CUDA_VISIBLE_DEVICES not set, use default setting
# 2026-08-14 05:04:18,438 - main - DEBUG - Torch CUDA: Detected 1 GPUs.
# 2026-08-14 05:04:18,438 - main - DEBUG -  * GPU 0: Tesla T4
# 2026-08-14 05:04:18,440 - main - DEBUG - Torch: CUDNN version = 90501
# 2026-08-14 05:04:18,440 - main - DEBUG - Torch: CUDNN is available.
# 2026-08-14 05:04:18,440 - main - DEBUG - ORT: Available providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# 2026-08-14 05:04:18,440 - main - INFO - Using GPU
# 2026-08-14 05:04:18,441 - main - INFO - ENV: http_proxy not set
# 2026-08-14 05:04:18,441 - main - INFO - ENV: https_proxy not set
# 2026-08-14 05:04:18,441 - main - INFO - ENV: HF_ENDPOINT not set
# 2026-08-14 05:04:18,443 - main - DEBUG - HOSTNAME: cf7bb9bcd7bb
# 2026-08-14 05:04:18,443 - main - DEBUG - ENV: PATH = /opt/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/root/.lhotse/tools/sph2pipe-2.5, LD_LIBRARY_PATH = /usr/lib64-nvidia
# 2026-08-14 05:04:18,443 - main - DEBUG -  * Loading Speaker Diarization Model
# Using diarization-3.1 model
# pytorch_model.bin: 100% 26.6M/26.6M [00:00<00:00, 45.8MB/s]
# config.yaml: 100% 221/221 [00:00<00:00, 1.42MB/s]
# 2026-08-14 05:04:20,525 - main - DEBUG -  * Loading ASR Model
# model.bin:   0% 0.00/3.09G [00:00<?, ?B/s]
# config.json: 2.39kB [00:00, 1.04MB/s]
#
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 2.54MB/s]
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
# vocabulary.json: 1.07MB [00:00, 24.6MB/s]
#
# tokenizer.json: 2.48MB [00:00, 20.9MB/s]
# model.bin: 100% 3.09G/3.09G [00:16<00:00, 190MB/s]
# 2026-08-14 05:04:40,115 - main - DEBUG -  * Loading PhoWhisper-large (VN, slot 2)
# config.json: 1.33kB [00:00, 6.42MB/s]
# pytorch_model.bin: 100% 6.17G/6.17G [03:07<00:00, 33.0MB/s]
# generation_config.json: 4.26kB [00:00, 13.7MB/s]
# tokenizer_config.json: 100% 805/805 [00:00<00:00, 6.81MB/s]
# vocab.json: 836kB [00:00, 8.13MB/s]
# tokenizer.json: 2.20MB [00:00, 22.6MB/s]
# merges.txt: 494kB [00:00, 14.1MB/s]
# normalizer.json: 52.7kB [00:00, 78.3MB/s]
# added_tokens.json: 2.08kB [00:00, 10.5MB/s]
# special_tokens_map.json: 2.08kB [00:00, 10.3MB/s]
# preprocessor_config.json: 100% 339/339 [00:00<00:00, 2.33MB/s]
# Device set to use cuda
# 2026-08-14 05:08:43,336 - main - DEBUG -  * Loading ChunkFormer-CTC (VN, slot 3)
# Fetching 10 files:   0% 0/10 [00:00<?, ?it/s]
# pytorch_model.bin:   0% 0.00/614M [00:00<?, ?B/s]
#
# README.md: 7.74kB [00:00, 8.49MB/s]
#
#
# global_cmvn: 0.00B [00:00, ?B/s]
#
#
# global_cmvn: 2.53kB [00:00, 2.69MB/s]
# .DS_Store: 100% 6.15k/6.15k [00:00<00:00, 16.1MB/s]
# Fetching 10 files:  10% 1/10 [00:00<00:03,  2.85it/s]
#
# dataset.tsv: 1.10kB [00:00, 8.32MB/s]
#
#
# config.yaml: 1.04kB [00:00, 5.80MB/s]
#
#
# .gitattributes: 1.52kB [00:00, 7.52MB/s]
#
#
# paper.pdf: 800kB [00:00, 20.1MB/s]
#
#
# vocab.txt: 89.1kB [00:00, 21.8MB/s]
#
# pytorch_model.bin:  44% 268M/614M [00:04<00:05, 59.5MB/s]
# pytorch_model.bin: 100% 614M/614M [00:10<00:00, 61.4MB/s]
# Fetching 10 files: 100% 10/10 [00:10<00:00,  1.03s/it]
# 2026-08-14 05:08:55,040 - main - DEBUG -  * PhoWhisper + ChunkFormer loaded on cuda
# DEBUG:main: * PhoWhisper + ChunkFormer loaded on cuda
# 2026-08-14 05:08:55,040 - main - DEBUG -  * Loading VAD Model
# DEBUG:main: * Loading VAD Model
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /root/.cache/torch/hub/master.zip
# 2026-08-14 05:08:57.429778150 [E:onnxruntime:Default, provider_bridge_ort.cc:2395 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1988 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library /content/sommelier_env/lib/python3.12/site-packages/onnxruntime/capi/libonnxruntime_providers_cuda.so with error: libcublasLt.so.13: cannot open shared object file: No such file or directory
#
# 2026-08-14 05:08:57.431538491 [W:onnxruntime:Default, onnxruntime_pybind_state.cc:1150 CreateExecutionProviderFactoryInstance] Failed to create CUDAExecutionProvider. Require cuDNN 9.* and CUDA 13.*. Please install all dependencies as mentioned in the GPU requirements page (https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html#requirements), make sure they're in the PATH, and that your GPU is supported.
# pytorch_model.bin: 100% 96.4M/96.4M [00:00<00:00, 118MB/s]
# config.yaml: 2.00kB [00:00, 9.84MB/s]
# Lightning automatically upgraded your loaded checkpoint from v1.2.7 to v2.6.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../../root/.cache/torch/pyannote/models--pyannote--embedding/snapshots/4db4899737a38b2d618bbd74350915aa10293cb2/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.2. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.8.1+cu102, yours is 2.7.1+cu126. Bad things might happen unless you revert torch to 1.x.
# 2026-08-14 05:09:00,127 - main - DEBUG -  * Speaker embedding model loaded for cross-chunk linking
# DEBUG:main: * Speaker embedding model loaded for cross-chunk linking
# diar_sortformer_4spk-v1.nemo: 100% 493M/493M [00:11<00:00, 41.9MB/s]
# [NeMo W 2026-08-14 05:09:23 nemo_logging:405] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: null
#     sample_rate: 16000
#     num_spks: 4
#     session_len_sec: 90
#     soft_label_thres: 0.5
#     soft_targets: false
#     labels: null
#     batch_size: 4
#     shuffle: true
#     num_workers: 18
#     validation_mode: false
#     use_lhotse: false
#     use_bucketing: false
#     num_buckets: 10
#     bucket_duration_bins:
#     - 10
#     - 20
#     - 30
#     - 40
#     - 50
#     - 60
#     - 70
#     - 80
#     - 90
#     pin_memory: true
#     min_duration: 80
#     max_duration: 90
#     batch_duration: 400
#     quadratic_duration: 1200
#     bucket_buffer_size: 20000
#     shuffle_buffer_size: 10000
#     window_stride: 0.01
#     subsampling_factor: 8
#
# [NeMo W 2026-08-14 05:09:23 nemo_logging:405] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: null
#     is_tarred: false
#     tarred_audio_filepaths: null
#     sample_rate: 16000
#     num_spks: 4
#     session_len_sec: 90
#     soft_label_thres: 0.5
#     soft_targets: false
#     labels: null
#     batch_size: 4
#     shuffle: false
#     num_workers: 18
#     validation_mode: true
#     use_lhotse: false
#     use_bucketing: false
#     drop_last: false
#     pin_memory: true
#     window_stride: 0.01
#     subsampling_factor: 8
#
# [NeMo W 2026-08-14 05:09:23 nemo_logging:405] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     is_tarred: false
#     tarred_audio_filepaths: null
#     sample_rate: 16000
#     num_spks: 4
#     session_len_sec: 90
#     soft_label_thres: 0.5
#     soft_targets: false
#     labels: null
#     batch_size: 4
#     shuffle: false
#     seq_eval_mode: true
#     num_workers: 18
#     validation_mode: true
#     use_lhotse: false
#     use_bucketing: false
#     drop_last: false
#     pin_memory: true
#     window_stride: 0.01
#     subsampling_factor: 8
#
# [NeMo I 2026-08-14 05:09:24 nemo_logging:393] PADDING: 16
# [NeMo I 2026-08-14 05:09:26 nemo_logging:393] Model SortformerEncLabelModel was successfully restored from /root/.cache/huggingface/hub/models--nvidia--diar_sortformer_4spk-v1/snapshots/9f17b10df44c0a4c8f3c86fbddc9ee2d6ab9ac08/diar_sortformer_4spk-v1.nemo.
# 2026-08-14 05:09:26,882 - main - DEBUG - All models loaded
# DEBUG:main:All models loaded
# 2026-08-14 05:09:26,883 - main - DEBUG - supported languages multilingual ['en', 'ko', 'ja', 'zh', 'es', 'fr', 'de', 'it', 'pt', 'ru', 'ar', 'hi']
# DEBUG:main:supported languages multilingual ['en', 'ko', 'ja', 'zh', 'es', 'fr', 'de', 'it', 'pt', 'ru', 'ar', 'hi']
# 2026-08-14 05:09:26,883 - main - DEBUG - using multilingual asr False
# DEBUG:main:using multilingual asr False
# 2026-08-14 05:09:26,883 - main - DEBUG - Scanning 0 audio files in /content/vi_audio (non-recursive)
# DEBUG:main:Scanning 0 audio files in /content/vi_audio (non-recursive)
# 2026-08-14 05:09:26,883 - main - INFO - [OPUS] No opus/ogg files found; skipping pre-decoding.
# INFO:main:[OPUS] No opus/ogg files found; skipping pre-decoding.
# Directory processing finished.
#  - Success: 0
#  - Failed: 0
# Total time: 0.00s

# %% [markdown]
# ## 7. Inspect output
#
# The script writes per-clip outputs under `/content/vi_audio/_final/_processed_llm-twelve-cases-*/<audio_name>/`.

# %%
import glob, json, pathlib

json_paths = sorted(glob.glob('/content/vi_audio/_final/**/*.json', recursive=True))
print(f'Found {len(json_paths)} result file(s):')
for p in json_paths:
    print(' -', p)

if json_paths:
    result = json.loads(pathlib.Path(json_paths[0]).read_text())
    print('\nMetadata:')
    print(json.dumps(result.get('metadata', {}), indent=2, ensure_ascii=False))
    print(f"\nFirst 3 segments of {len(result.get('segments', []))}:")
    for seg in result.get('segments', [])[:3]:
        print(json.dumps(seg, indent=2, ensure_ascii=False))
# Out:
# Found 0 result file(s):

# %% [markdown]
# ## Troubleshooting
#
# **T4 OOM during MoE:** the three ASR models (Whisper-large-v3, PhoWhisper-large, ChunkFormer-CTC) plus Sortformer/pyannote barely fit in 16 GB. Either upgrade the runtime, or as a stopgap edit `asr_MoE()` in `main_original_ASR_MoE.py` to use `ThreadPoolExecutor(max_workers=1)` so models run sequentially instead of in parallel.
#
# **`chunkformer` import error:** the package was added in step 3.4 above — if you skipped it, run `!pip install chunkformer` and **restart the runtime** (Runtime → Restart runtime).
#
# **HF 401 on Sortformer / pyannote:** accept the license on each gated model page (`pyannote/segmentation-3.0`, `pyannote/embedding`, `nvidia/diar_sortformer_4spk-v1`) while logged in to the same HF account whose token you pasted.
#
# **Empty `text_phowhisper` / `text_chunkformer` but `text_whisper` populated:** check the cell output for `PhoWhisper failed:` / `ChunkFormer failed:` log lines — the MoE swallows per-model errors so Whisper alone still produces a transcript.
